# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %%
# Lab | Imbalanced data
# We will be using the files_for_lab/customer_churn.csv dataset to build a churn predictor.

# Instructions
# 1 Load the dataset and explore the variables.
# 2 We will try to predict variable Churn using a logistic regression on variables tenure, SeniorCitizen,MonthlyCharges.
# 3 Extract the target variable.
# 4 Extract the independent variables and scale them.
# 5 Build the logistic regression model.
# 6 Evaluate the model.
# 7 Even a simple model will give us more than 70% accuracy. Why?
# Synthetic Minority Oversampling TEchnique (SMOTE) is an over sampling technique based on nearest neighbors that adds new points between existing points. Apply imblearn.over_sampling.SMOTE to the dataset. Build and evaluate the logistic regression model. Is it there any improvement?

# %%
# 1 Load the dataset and explore the variables.
churn=pd.read_csv('files_for_lab/customer_churn.csv')
churn.head(5)
#churn.Outcome.value_counts(dropna=False)


# diabetes=pd.read_csv('diabetes.csv')
# diabetes.head(50)
# diabetes.Outcome.value_counts(dropna=False)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 7   6713-OKOMC  Female              0      No         No      10           No
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# ...

# %%
list(churn.columns.values)
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %%
# 3 Extract the target variable.
# X/y split
X = churn.drop('Churn',axis = 1)
y = churn['Churn']

# %%
# 3 Extract the target variable
correlations_matrix = X.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()
# if you are young you are likly to not have many pregnancies
# if you are old then you are likely to have more pregnancies than younger

# %%
# 3 Extract the target variable
data1 = churn[["SeniorCitizen","tenure","MonthlyCharges","Churn"]]

# %%
# 3 Extract the target variable
data1.head(5)
# Out:
#    SeniorCitizen  tenure  MonthlyCharges Churn
# 0              0       1           29.85    No
# 1              0      34           56.95    No
# 2              0       2           53.85   Yes
# 3              0      45           42.30    No
# 4              0       2           70.70   Yes

# %%
# 3 Extract the target variable
list(data1.columns.values)
# Out:
# ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'Churn']

# %%
## Standardization of independent variables

# %%
# we do logistic regression, when no multicollinearity, 
# we 
# here we start scaling, so need to do train-test-split before
# if we start doing the scaling we have to do our train split before
#  if we start 
# there are differences in the selection of random state 
# 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0) # default fraction is .2

# %%
y_train.head()
# Out:
# 3296     No
# 6397     No
# 6043    Yes
# 5309     No
# 3000    Yes
# Name: Churn, dtype: object

# %%
X_train.head()
# X train row data match up with y train table
# because of transformaation and creating a new data frame has reset the index on my x train skilled
# it has not changed the order of the rows
# it only reset the index
# we still need to match up the indexes x train and y train
# if i reset the index later it can be matched up
# reset the index on y train and y test.
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3296  2229-VWQJH  Female              0      No         No      24
# 6397  7994-XIRTR    Male              1      No         No      54
# 6043  6338-AVWCY    Male              0      No         No       3
# 5309  0704-VCUMB  Female              0     Yes         No      61
# 3000  7613-LLQFO    Male              0      No         No      12
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 3296          Yes                No             DSL                   No
# 6397          Yes                No             DSL                   No
# 6043           No  No phone service             DSL                   No
# 5309          Yes                No              No  No internet service
# 3000          Yes               Yes     Fiber optic                   No
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# ...

# %%
y_train = y_train.reset_index(drop=True) 
# needed because the transformation also reset the index for X_train_scaled
# so we need this for y_test as well...
y_test = y_test.reset_index(drop=True)

# %%
y_train.head()
# Out:
# 0     No
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# Name: Churn, dtype: object

# %%
# logistic regression model to calculate the y in the model
# if we have a model we can start making predictions
# we do a different prediction function
# the second column gives the probability is that my targe = 1 
# we are after predicted y values in the 2 column
#  i take the 2nd column and i have here 1 over - 1
from sklearn.linear_model import LogisticRegression

LR = LogisticRegression(random_state=0, solver='lbfgs')
LR.fit(X_train_scaled, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24180\4093539924.py in <module>
#       8
#       9 LR = LogisticRegression(random_state=0, solver='lbfgs')
# ---> 10 LR.fit(X_train_scaled, y_train)
#
# NameError: name 'X_train_scaled' is not defined

# %%
data1 = churn[["SeniorCitizen","tenure","MonthlyCharges","Churn"]]

# %%
data1.shape

# %%
data1.corr()

# %%
# X/y split
X = data1.drop('Charn',axis = 1)
y = data1['Charn']
